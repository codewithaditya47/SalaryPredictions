# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithaditya47/SalaryPredictions/blob/main/SalaryPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Salary.csv')

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

plt.xlabel('Experience')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.982427
# Salary                  0.982427  1.000000

# %%
y=df['Salary']
X=df[['YearsExperience']]

# %%
X.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (26, 1)

# %%
X.shape
# Out:
# (35, 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
print(regression.intercept_)
# Out:
# [33283.30229267]
# 82738.07692307694

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=root_mean_squared_error(y_test,y_pred)

# %%
print(mae)
print(mse)
print(rmse)
# Out:
# 6782.1688891876265
# 54958757.926339835
# 7413.417425610124

# %%
R2_score=r2_score(y_test,y_pred)
print(R2_score)
# Out:
# 0.9094204577612955

# %%
regression.predict(scaler.transform([[20]]))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([200938.68525914])
